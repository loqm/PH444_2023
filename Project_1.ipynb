# %% [markdown]
# #**Abstract**

# %% [markdown]
# ##**The complex Maxwell stress tensor theorem: The imaginary stress tensor and the reactive strength of orbital momentum. A novel scenery underlying electromagnetic optical forces.**##

# %% [markdown]
# This research discovers a new phenomenon in photonics and classical electrodynamics that affects the mechanical efficiency of light on matter. The study introduces the concept of reactive strength of orbital momentum and the imaginary Lorentz force, which play important roles in the optical force exerted by light on particles. These findings have significant implications for the design of optical manipulation techniques, enabling efficient manipulation without increasing illuminating power and lowering dissipation and heating.

# %% [markdown]
# #**Introduction**

# %% [markdown]
# In this passage, we discuss the complex Maxwell stress tensor and its importance in understanding electromagnetic forces in optical manipulation. The real part of the Maxwell stress tensor is well-known and describes the time-averaged or real Lorentz forces on a volume of charges and currents. However, the imaginary part of the complex Maxwell stress tensor, related to the exchange of reactive momentum, has so far been ignored. In this report we explain the complex Maxwell stress tensor theorem and understand the concept of the imaginary Lorentz force and the reactive strength of orbital momentum. This reactive force is not observable on time averaging since its net value is zero, but it exists instantaneously due to the transfer of the reactive momentum, which alternates with time, between the wave and the body.
# Hence, the ILF is a basically fundamental dynamic phenomenon, inherent to the emergence of  electromagnetic optical forces, being also
# associated to the appearance of reactive energy, reactive work, and reactive helicity.  The RLF having been for many years a well-known workhorse in the design of RF antennas, and recently studied in nano and micro-antennas etc. Therefore, like in RF antenna design one aims to diminish the reactive power and reactive work to increase the radiation efficiency, the theory put forward in this work constitutes a tool to act on the ROM and ILF in order to optimize a desired radiation pressure in optical manipulation.
# \
# \
# *Flow of the report*
#
# First, we establish the complex stress tensor theorem
# in an embedding vacuum or air; defining the ILF, IMST,
# and ROM for general time-dependent light fields,
# and discussing their respective physical meaning.
#
# Secondly, we shall characterize the Instantaneous maxwell stress theorem flow in terms
# of the magnetic and electric spin momenta of the total
# (i.e., incident plus scattered) field. . We then express
# the ILF by what we put forward as the reactive strength of Poynting momentum, obtained from the electric and magnetic spin and orbital momenta, while we show that the RLF may be written as the sum of the imaginary spin and orbital momenta. We also establish the imaginary field (i.e., Poynting) momentum representation with sources in terms of the reactive orbital and spin momenta.
#
# After demonstrating the general CMST and near-field nature of the IMST,
# we go on taking some examples , First example will be of Linearly polarized plane wave impinging on a low refractive index small dielectric particle. \\
# Second example will be of Linearly polarized Gaussian wave impinging on a small dielectiric particle of low refractive index, which will be our tut problem. \\
# Then, we also take one example of a plasmonic particle and how it changes therautical calculations.

# %% [markdown]
# # **Complex Maxwell Stress Tensor Theorem**

# %% [markdown]
# In the paper, a homogenous medium with $\epsilon = \mu = 1$ in Gaussian units with a body on which studies are undertaken. In the paper, to study the imaginary effects, all the physical quantities are analytically continued in the lower half complex plane $\tau=t-is$.\
# We start with analytic signals, ${\mathbf{E}} (r,t) ,{\mathbf{H}}(r,t),{\mathbf{J}}(r,t)$  associated to the real vectors $\mathcal{E}(r,t) ,\mathcal{H}(r,t),\mathcal{J}(r,t)$ which are analytically continued into the lower half complex plane τ = t − is. Generically
# denoting each of these analytic functions as $\vec{\mathcal{V}}(r,t,s)$ ,
# they are expressed by the Fourier integral : \
# \begin{equation} \quad \vec{\mathcal{V}}(r,t,s) \equiv \vec{\mathcal{V}}(r,\tau) =  \int_{0}^{\infty} exp(-i\omega\tau) \vec{\mathcal{D}}(r,\omega) \,d\omega
# \end{equation}
# $ \qquad $ where , $ \vec{\mathcal{D}}(r,\omega) $ is  $  \omega $ - Fourier spectrum of the real function $ \vec{\mathcal{D}}(r,t)$ which generally denotes $ \qquad \vec{E}(r,t) ,\vec{H}(r,t) $ or $\vec{J}(r,t)$
#
# Complex derivatives in terms of $\tau$:
# \begin{equation}
#     \partial_{\tau} = \frac{1}{2}(\partial_t + i\partial_s), \quad
#      \partial_{{\tau}}^* = \frac{1}{2}(\partial_t - i\partial_s) \quad.....(1)
# \end{equation}
#
# \begin{equation}
#     \partial_{\tau}\mathbf{V^*} = \partial_t \mathbf{V^*} = i\partial_s \mathbf{V^*}, \quad
#     \partial_{{\tau}}^*\mathbf{V} = \partial_t \mathbf{V} = - i\partial_s \mathbf{V} \quad.....(2)
# \end{equation}
#
# Using eqautions (1) and (2), writing Maxwell Equations for complex analytical signals:
#
# \begin{equation}
#     \nabla \cdot \mathbf{E} = 4\pi\rho, \quad
#     \nabla \cdot \mathbf{H} = 0, \quad
#     \nabla\times\mathbf{E} = -\frac{1}{c}{\partial_\tau^*\mathbf{H}}, \quad
#     \nabla\times\mathbf{H} = \frac{1}{c}{\partial_\tau^*\mathbf{E}} + \frac{4\pi}{c}\mathbf{J}\quad .....(3)
# \end{equation}
#
# Now, in the paper, it was argued that for complex Lorentz force $\mathbf{F}$ is taken from complex sources. This complex force can be written in terms of conservation of complex linear momentum:
# \begin{equation}
#     \mathbf{F}(\mathbf{r},t,s) = \frac{\partial}{\partial t}\mathbf{P}_{mech}(\mathbf{r},t,s) = \frac{1}{2}\int_V d^3r'\left[\rho^*(\mathbf{r}',t)\mathbf{E}(\mathbf{r}',t) + \frac{\mathbf{J^*}(\mathbf{r}',t)}{c}\times\mathbf{B}(\mathbf{r}',t)\right] \quad.....(4)
# \end{equation}
#
# Substituting $\rho^*$ and $\mathbf{J^*}$ from Maxwell equations (3) and using equations (1), (2) and also, we introduce scaled Poynting momentum $\mathbf{G} = \frac{1}{c^2}\mathbf{S} = \frac{1}{8\pi c}[\mathbf{E} \times \mathbf{B^*}]$. After all this and some mathematics, paper takes it to this:
#
# \begin{equation}
# F_i = \partial_t P_{mech,i} = -\int_V d^3r \partial_tG_i^* + \int_{\partial V} d^2r T_{ij}n_j + \frac{i}{8\pi}\int_V d^3r Im[B_j^*\partial_i B_j - E_j^*\partial_iE_j] \quad.....(5)
# \end{equation}
# where $n_j$ denotes jth Cartesian component of unit outward normal to the surface V, and $T_{ij}$ is Complex Maxwell Stress Tensor given by:
# \begin{equation}
# T_{ij}(\mathbf{r},s,t) = \frac{1}{8\pi}\left(E_i(\mathbf{r},s,t)E_j^*(\mathbf{r},s,t) + B_i(\mathbf{r},s,t)B_j^*(\mathbf{r},s,t) - \frac{1}{2}\delta_{ij}(|\mathbf{E}|^2 + |\mathbf{B}|^2)\right)\quad.....(6)
# \end{equation}
#
# In equation (5), for the force, there appears orbital momentum due to EM field. The orbital momentum of EM field:
# \begin{equation}
# \mathbf{P^O}=\frac{1}{2}(\mathbf{P^O_e}+\mathbf{P^O_m})\\
# (P^O_e)_i = \frac{1}{8\pi \omega}Im[E^*_j\partial_iE_j] \quad (P^O_m)_i = \frac{1}{8\pi \omega}Im[B^*_j\partial_iB_j],\quad
# \omega=kc \quad .....(7)
# \end{equation}
# Now, since 3rd term of equation (5) is completely imaginary, the breakdown of force into real and imaginary parts is as follows:
#
# \begin{equation}
# F^R_i = -\int_V d^3r \partial_t G^R_i + \int_{\partial V}d^2r T^R_{ij}n_j \quad.....(8) \\
# F^I_i = -\int_V d^3r \partial_t G^I_i + \int_{\partial V}d^2r T^I_{ij}n_j+\omega \int_V d^3r[\mathbf{P^O_m}-\mathbf{P^O_e}]_i \quad.....(9)
# \end{equation}
# The superscripts R and I denotes real and imaginary parts respectively. And subscript i denotes ith component.
#
# The equation (9) gives us the Imaginary Lorentz Force (ILF) acting on the particle. It comes from time change of IPM, the flux of IMST over the volume in which particle is stored, term containing integral of difference of magnetic and electric orbital momentum, this term, paper has defined to be reactive strength of orbital momentum (ROM) stored in volume V around the particle.
#
# $\mathbf{F^I}$, ILF, also called as reactive force on object of volume $V_O$, has zero time average. On the other hand, RLF is not zero on time averaged scale.
#
#
# \\
#
# Now, paper talks about specific expressions for EM fields, here **Time harmonic fields**:
#
# So,
# \begin{equation}
# \mathbf{E} = \mathbf{E(r)}exp(-i\omega t) \quad \mathbf{B} = \mathbf{B(r)}exp(-i\omega t)
# \end{equation}
#
# In this case the time derivate of complex poynting momentum $[\mathbf{E \times B^*}]$ term will go to zero and hence, the force equation (5) will here become:
#
# \begin{equation}
# F_i = \int_{\partial V} d^2r T_{ij}n_j + i\omega\int_V d^3r (\mathbf{P^O_m-P^O_e})_i\quad .....(10)
# \end{equation}
#
# For, the real part of force, we take time-average, where second term will go to zero, and hence:
#
# \begin{equation}
# Re\{F_i\}=<F_i> = \int_{\partial V} d^2r <T_{ij}>n_j \quad.....(11)
# \end{equation}
# where $<T_{ij}>$ is just the real part of $T_{ij}$.
#
# The imaginary part of force equation (10) will be:
#
# \begin{equation}
# Im\{F_i\}=F^I_i = \int_{\partial V} d^2r T_{ij}^In_j +\omega\int_V d^3r (\mathbf{P^O_m-P^O_e)_i}\quad.....(12)
# \end{equation}

# %% [markdown]
# # **The instantaneous Maxwell stress tensor (Instantaneous MST)**

# %% [markdown]
# At this point it is convenient to introduce the instantaneous Maxwell stress tensor, that gives rise to the alternating instantaneous ILF, built by the fields $\mathbf{E}(r,t)$  and  $\mathbf{B}(r,t)$. Like for other instantaneous time-harmonic quantities

# %%
from google.colab.patches import cv2, cv2_imshow
img = cv2.imread("/content/Tensor.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=596x197 at 0x7FE062018640>

# %% [markdown]
# writing time dependent and independent part of tensor we have the following :

# %%
img2 = cv2.imread("/content/Tensor_time_dep.jpg")
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=598x277 at 0x7FE062018250>

# %% [markdown]
# We can see that the $<T_{ij}(r,t)>$ does not change sign with time, as expected from the instantaneous MST part associated with the time-averaged flow of momentum, the term containing the reactive Maxwell stress tensor, $T^{I}_{ij}(r,t)$, alternates its sign at frequency 2ω following the variation of sin 2ωt. This is in accordance with the interpretation of the imaginary part of equation (10) in CMST theorem being
# related to the ROM flux, i.e., the IMST, going back and forth from the object volume $V_0$ with zero time average.

# %% [markdown]
# When we take Volume $V$ to $V_{\infty}$ (i.e. large sphere limits) in equation (12) from previous section, we get only diagonal elements of CMST remains since CMST is real in far zone.
# so
# \begin{equation}
# \qquad {{F^I_i}}  ≡ ω \int_{V_{∞}} d^{3}r ({P^{O}_{m}} - {P^{O}_{e}} )_i \quad .....(13)
# \end{equation}
# equating both equations, we get
# \begin{equation}
#  \int_{∂V} T^{I}_{ij} n_{j} d^{2}r    = ω \int_{V_{∞} - V} d^{3}r (P^{O}_{m} - P^{O}_{e} ) \quad .....(14)
#  \end{equation}

# %% [markdown]
# Now we are in position to have the overall perspective
# of the CMST theorem in both the far-field and near-field
# regions, and to understand how the flow IMST builds up
# the ROM inside and outside the particle, with the ILF
# being generated. Figure 1 illustrates the process. It should
# be recalled that the illuminated object behaves like an
# antenna, so that the interaction also conveys a reactive
# work on the charges, building-up reactive power which
# hinders the efficiency of radiated scattered energy.

# %%
img3 = cv2.imread("/content/Fig1_emt.jpg")
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=353x427 at 0x7FE063879490>

# %% [markdown]
# In this figure an electromagnetic wave, (for example a
# monochromatic plane wave, as illustrated ), impinges on a body,
# charges are separated, thus inducing multipoles. The object feels a
# time-averaged Lorentz force, RLF, associated to the field (i.e.,
# Poynting) momentum flux, RMST, flowing into a far-field surface, (e.g.,
# spherical as shown). However, there also appears a flow, IMST, of
# imaginary field momentum, related to momentum flux going back
# and forth across a near-field surface, with zero time-average, which
# accumulates reactive strength of orbital momentum, ROM, stored
# both inside and in the near-field of the object, yielding a reactive
# force, ILF, on the body.

# %% [markdown]
# **The canonical and spin momenta and the complex lorentz force** \\
# In this section we show the relation between complex lorentz force and the momenta. Using following identities :
# \begin{equation}
# a^{*} \times ( \nabla \times a ) = a^{*}_{j} \partial_{i} a_{j} - a^{*}_{j} \partial_{j} a_{i}
# \end{equation}
# and Levi-Civita Tensor:
# \begin{equation}
# ϵ_{ijk} ϵ_{klm} = δ_{il}δ_{jm} - δ_{im}δ_{jl}
# \end{equation}
# Hence, using the above identity, we may write these spin
# momentum densities as :
# \begin{equation}
#    P^{S}_{e} = \frac{1}{16\pi ω}\ \nabla\times Im(\mathbf{{E^{*}×E}}) = \frac{1}{8\pi ω}\ \nabla Im(\partial_{j} (E^{*}_{i}E_{j}))
# \end{equation}
# \begin{equation}
#    P^{S}_{m} = \frac{1}{16 \pi ω}\ \nabla ×Im(\mathbf{{B^{*}×B}}) = \frac{1}{8\pi ω}\ \nabla Im(\partial_{j} (B^{*}_{i}B_{j}))
# \end{equation}

# %% [markdown]
# Therefore from equation (12) of CMST Theorem section we finally have
# \begin{equation}
#   \mathcal{F}^{I} = ω \int_{V}  d^{3}r [(P^{S}_{m} - P^{S}_{e}) + (P^{O}_{m} - P^{O}_{e})] \quad
# \end{equation}
# From equation (14) we get
# \begin{equation}
# \int_{V}  d^{3}r [(P^{S}_{m} - P^{S}_{e}) = \int_{V_{∞}-V}  d^{3}r (P^{O}_{m} - P^{O}_{e})]\quad
# \end{equation}
# And thus we obtain that as V approaches $V_{∞}$ , we have
# \begin{equation}
# \int_{V_{∞}}  d^{3}r (P^{S}_{m} - P^{S}_{e})] = 0\quad
# \end{equation}
# We have shown that the overall spin
# momentum of the field emitted, or scattered, by a dipolar particle is zero.

# %% [markdown]
# # **Example 2: Linearly polarized plane wave impinging on a low refractive index small dielectric particle**

# %% [markdown]
# Here, the paper has an example of a purely dielectric particle sphere, with following parameters:\
# Refractive index **n = 1.59** \
# Radius **a = 50 nm**
#
# The particle is illuminated by a linearly propagating plane wave:
# \
# \
# \begin{align}
# \textbf{E} = E_0e^{ikz} \hat{x}, \quad \textbf{B} = E_0e^{ikz} \hat{y} \quad .....(15)
# \end{align}
# \
# From supplementary material of the paper, in appendix E, which is also explained in tut question, the time-averaged and the reactive force on the particle are computed for a dipole, in this case electric dipole:
# \
# \begin{equation}
# <F_i>=\frac{1}{2}Re\{\alpha_eE_j\partial_iE_j^*\}, \quad Im\{F_i\}=-\frac{1}{2}Im\{\alpha_eE_j\partial_iE_j^*\}
# \end{equation}
# \
# Using given EM fields from equation (15), real force (time-averaged) and imaginary force are:
# \begin{align}
# <\mathcal{\textbf{F}}>=\frac{1}{2}\alpha_e^IkE_0^2 \hat{z}, \quad \textbf{F}_e^I=\frac{1}{2}\alpha_e^RkE_0^2\hat{z} \quad .....(16)
# \end{align}
# \
# Now, how to find real and imaginary polarizibilities, $\alpha_e^R$ and $\alpha_e^I$ respectively.
#
# We use Clausius-Mossotti relation between electric polarisibility and refractive index:
# \
# \
# \begin{align}
# \alpha_e = \frac{3}{4\pi}{V}(\frac{n^2-1}{n^2+2})
# \end{align}
# \
# Where $V$ is volume of the particle which is $\frac{4\pi}{3}a^3$. Now, since $n$ has no imaginary part, $\alpha_e^I$ will be zero. So, we will get $\alpha_e^R$ from the equation.
# \
# Plotting $k\alpha_e^R$ vs wavelength $\lambda$, where $k=\frac{2\pi}{\lambda}$ in figure 1(a).
#
# Now, for ILF, using equation 15, taking $E_0 = 1$:  \\
# $\mathbf{F^I_e} = \frac{1}{2}k\alpha_e^R \hat z$ and since $\alpha^I_e=0 \implies <\mathbf{F}>=0$
# Plotting imaginary force for this particle in figure 1(b).
#
# In the paper, imaginary lorentz force (ILF) is broken into $F^{IMST}$ and $F^{ROM}$. For the former, we need to solve equation the first term in RHS of equation (12) in Complex Maxwell Stress Theorem section, which is as follows:
# \begin{equation}
# Im\{F_i\}=F^I_i = \int_{\partial V} d^2r T_{ij}^In_j +\omega\int_V d^3r (\mathbf{P^O_m-P^O_e)_i}\quad \\
# T_{ij}^I = \frac{1}{8\pi} Im\{E_i E_j^* + B_j B_i^*\}
# \end{equation}
#
# Solving this is not trivial, since electric fields in the vicinity of particle will change, so appendix D in supplementary material has given an approximated solution for $F^{IMST}$, which is given in equation (55) in paper:
# \begin{equation}
# F^{IMST}=Im\left\{\int_{\partial V_0} d^2\mathbf{r}\, T^{\mathrm{mix}}_{kj}n_j \right\}= -\frac{1}{10}\{\alpha_{e}^I\nabla\mathbf|{E}|^2 - \alpha_{m}^I\nabla\mathbf|{B}|^2\} + \frac{4\pi}{5}\omega\{(\alpha^R_m - \alpha^R_e)\langle \mathbf{g}\rangle + (\alpha_{e}^I-\alpha_{m}^I)\mathbf{g^I} + 2(\alpha_e^R P_e^O - \alpha_m^R P_m^O)\} \\
# <g> = \frac{1}{8\pi c}Re\{\mathbf{E\times B^*}\}
# \end{equation}
#
#
# Since, particle in this example is purely dielectric, $\alpha_m = 0$, using this and other values from the example, it comes to be:
#
# \begin{equation}
# F^{IMST} = \frac{1}{5} \{ \frac{1}{2} \alpha^R_e k |E_0|^2 \} = \frac{1}{5} F_e^I
# \end{equation}
#
# So, it comes to be one fifth of ILF.
#
# Now, calculating force due to reactive orbital momentum storage is easy, we just subtract $F^{IMST}$ from ILF.
#
# Both of them are plotted for this example in figure 1(c) and 1(d) respectively.

# %%
import matplotlib.pyplot as plt
import numpy as np
n = 1.59
a = 50
wavelength = np.arange(450,1100)
k_alp = (a**3)*((n**2-1)/(n**2+2))*(2*3.141/wavelength)
F_im = (1/2)*k_alp
F_imst = (1/5)*F_im
F_rom = F_im - F_imst
figure, axis = plt.subplots(2, 2)
axis[0,0].plot(wavelength,k_alp)
axis[0,0].set_title(r'$1(a)\quad k\alpha_e^R$ vs $\lambda (nm)$')
axis[1,0].plot(wavelength,F_im, color='r')
axis[1,0].set_title(r'1(b) $\quad F^I_e$ vs $\lambda$')
axis[0,1].plot(wavelength,F_imst)
axis[0,1].set_title(r'$1(c)\quad F^{IMST}$ vs $\lambda (nm)$')
axis[1,1].plot(wavelength,F_rom)
axis[1,1].set_title(r'$1(d)\quad F^{ROM}$ vs $\lambda (nm)$')
figure.tight_layout(pad=1.0)
plt.show()

# %% [markdown]
# # **The time-averaged Poynting momentum with sources and the imaginary Lorentz force**

# %% [markdown]
#  We previosly saw that the imaginary lorentz force is related
# \begin{equation}
# \mathbf{F}^I=ω\int_Vd^3r[(P^S_m-P^S_e)+(P^o_m-P^o_e)]
# \end{equation}
# Let us now establish the compatibility of time averaged poynting momentum with the imaginary lorentz force.We know the definition of time averaged poynting momentum.
# \begin{equation}
# <g>=\frac{<S>}{c^2}=(\frac{1}{8πc})Re{(\mathbf{E}×\mathbf{B^*})}
# \end{equation}
#
# Using the langrangian formulation in electrodynamics the above equation can be written completely in terms of electric field as follows:
# \begin{equation}
# <g>=P^S_m+P^O_e+\frac{1}{2ω}Im({ρ^*\mathbf{E}})\quad.....(17)
# \end{equation}
# Similarly eliminating electric field in the definition of $<g>$, we obtain in terms of magnetic momenta we get
# \begin{equation}
# <g>=P^S_m+P^O_m-\frac{1}{2ω}Im(\mathbf{j^*}×\mathbf{B})\quad.....(18)
# \end{equation}
# Adding the above two equations and considering there is no source we get
# \begin{equation}
# <g>=(P^O_e+P^O_m)/2+(P^S_e+P^S_m)/2
# \end{equation}
# Subtracting equation 17 from 18 and integrating in V we get the imaginary lorentz force in terms in spin and canonical momentum.
# Similarly if we do this for the imaginary field momentum following the same procedure we get following two important equations
#  \begin{equation}
#  <\mathbf{F}>=2ω\int_V d^3r(P^{SI}+P^{OI})
#  \end{equation}
#  where $P^{SI}=\frac{P^{SI}_e+P^{SI}_m}{2}$ and $P^{OI}=\frac{P^{OI}_e+P^{OI}_m}{2}$
#  Above equation is the equation for Real lorentz force in terms of imaginary momenta.
#  The second equation is for imaginary poynting momentum in terms of reactive spin and orbital momentum
#  \begin{equation}
#  \mathbf{g}^I=\mathbf{P^S+P^O}+\frac{1}{4kc}Re({\mathbf{ρ^*}\mathbf{E}-\frac{1}{c}\mathbf{j^*}\times \mathbf{B}})
#  \end{equation}
#  where
#  \begin{equation}\mathbf{P}^S=\frac{\mathbf{P}^{SI}_m-\mathbf{P}^{SI}_e}{2}\quad  \textrm{and}\quad \mathbf{P}^O=\frac{\mathbf{P}^{OI}_m-\mathbf{P}^{OI}_e}{2}
#  \end{equation}

# %% [markdown]
# # **Example 5: Linearly polaized plane wave incident on a plasmonic particle**

# %% [markdown]
# Plasmonic nanoparticles can interact with the EM fields in such a way that they can absorb or extract energies from it. In the paper, it was proposed that they may extract energy from reactive power whenever condition for resonance between RLF and ILF occur.
#
# To demonstrate, they have experimented with gold nanoparticle sphere of radius a=50 nm.
#
# They used experimental plots of real and reactive forces to compare with the equation we used earlier in example 2.
#
# We also try to plot the same. We used refractive index values of gold at different wavelengths from internet resource [1]. Figure 1(a) contains the data from it, real and imaginary refractive index of gold.
# Figure 1(b) has real (time-averaged) and imaginary forces corresponding to same equations used in previous examples of dielectric particle. But, if we compare them with the experimental results obtained in paper figure below, we see a striking change in the feature of the plots of forces, notably the imaginary force. Authors in the paper argue that it is due to the nature of particle here is plasmonic, it extracts the energy from reactive quantities, hence imaginary force reduces.

# %%
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2,cv2_imshow
wavelength = np.array([450.86,459.2,467.87,476.87,486.22,495.94,506.06,516.6,527.6,539.07,551.05,563.57,576.68,590.41,604.81,619.93,635.82,652.55,670.19,688.81,708.49,729.32,751.43,774.91,799.9])
n = np.array([1.502,1.426,1.346,1.242,1.087,0.916,0.755,0.608,0.492,0.402,0.346,0.306,0.268,0.236,0.212,0.194,0.178,0.166,0.161,0.16,0.161,0.164,0.17,0.176,0.181])
k = np.array([1.87588,1.846,1.81463,1.796,1.79738,1.84,1.9565,2.12,2.32625,2.54,2.73063,2.88,2.94063,2.97,3.015,3.06,3.07,3.15,3.44581,3.8,4.08769,4.357,4.61019,4.86,5.12581])
a = 50
k_alpre = np.zeros(len(k))
k_alpim = np.zeros(len(k))

for i in range (len(k)):
  k_alpre[i] = (a**3)*(( (n[i]**2-k[i]**2-1)*(n[i]**2-k[i]**2+2)+(2*n[i]*k[i])**2 )/( (n[i]**2-k[i]**2+2)**2+(2*n[i]*k[i])**2 ))*(2*3.141/wavelength[i])
  k_alpim[i] = (a**3)*(( ((6*n[i]*k[i]) )/( (n[i]**2-k[i]**2+2)**2+(2*n[i]*k[i])**2 ))*(2*3.141/wavelength[i]))
F_im = (1/2)*k_alpre
F_re = (1/2)*k_alpim
F_imst = (1/5)*F_im
F_rom = F_im - F_imst
figure, axis = plt.subplots(2, 2)
axis[0,0].plot(wavelength,k_alpim, label=r'$k\alpha_e^I$', color='r')
axis[0,0].plot(wavelength,k_alpre, label=r'$k\alpha_e^R$', color='b')
axis[0,0].set_title(r'$1(b)\quad k\alpha_e$ vs $\lambda (nm)$')
axis[0,0].legend()
axis[1,0].plot(wavelength,F_im, label=r'$F^I$', color='r')
axis[1,0].plot(wavelength,F_re, label=r'$F^R$', color='b')
axis[1,0].set_title(r'$1(b)\quad F$ vs $\lambda (nm)$')
axis[1,0].legend()
axis[0,1].plot(wavelength,F_imst)
axis[0,1].set_title(r'$1(c)\quad F^{IMST}$ vs $\lambda (nm)$')
axis[1,1].plot(wavelength,F_rom)
axis[1,1].set_title(r'$1(d)\quad F^{ROM}$ vs $\lambda (nm)$')
figure.tight_layout(pad=1.0)
plt.show()

img = cv2.imread('/content/fig4.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=863x636 at 0x7F8BDDDB5850>

# %% [markdown]
# # **Hypothetical example to compare with example 5**

# %% [markdown]
# To compare the results of example 5, paper introduces a hypothertical paritcle named $Au_3$ which has real part of refractive index same as Au but imaginary part is zero.
#
# So plotting similar plots for this hypothetical particle:
#
# Here, the computed therautical plots matches with that of experimental (maybe simulated) data plots, so that implies no resonance occurs here and hence imaginary refratice index has the role to play in it.

# %%
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2,cv2_imshow
wavelength = np.array([450.86,459.2,467.87,476.87,486.22,495.94,506.06,516.6,527.6,539.07,551.05,563.57,576.68,590.41,604.81,619.93,635.82,652.55,670.19,688.81,708.49,729.32,751.43,774.91,799.9])
n = np.array([1.502,1.426,1.346,1.242,1.087,0.916,0.755,0.608,0.492,0.402,0.346,0.306,0.268,0.236,0.212,0.194,0.178,0.166,0.161,0.16,0.161,0.164,0.17,0.176,0.181])
# k = np.array([1.87588,1.846,1.81463,1.796,1.79738,1.84,1.9565,2.12,2.32625,2.54,2.73063,2.88,2.94063,2.97,3.015,3.06,3.07,3.15,3.44581,3.8,4.08769,4.357,4.61019,4.86,5.12581])
a = 50
k_alpre = np.zeros(len(k))
k_alpim = np.zeros(len(k))

for i in range (len(k)):
  k_alpre[i] = (a**3)*(( (n[i]**2-k[i]**2-1)*(n[i]**2-k[i]**2+2)+(2*n[i]*k[i])**2 )/( (n[i]**2-k[i]**2+2)**2+(2*n[i]*k[i])**2 ))*(2*3.141/wavelength[i])
  # k_alpim[i] = (a**3)*(( ((6*n[i]*k[i]) )/( (n[i]**2-k[i]**2+2)**2+(2*n[i]*k[i])**2 ))*(2*3.141/wavelength[i]))
F_im = (1/2)*k_alpre
F_re = (1/2)*k_alpim
F_imst = (1/5)*F_im
F_rom = F_im - F_imst
figure, axis = plt.subplots(2, 2)
axis[0,0].plot(wavelength,k_alpim, label=r'$k\alpha_e^I$', color='r')
axis[0,0].plot(wavelength,k_alpre, label=r'$k\alpha_e^R$', color='b')
axis[0,0].set_title(r'$1(b)\quad k\alpha_e$ vs $\lambda (nm)$')
axis[0,0].legend()
axis[1,0].plot(wavelength,F_im, label=r'$F^I$', color='r')
axis[1,0].plot(wavelength,F_re, label=r'$F^R$', color='b')
axis[1,0].set_title(r'$1(b)\quad F$ vs $\lambda (nm)$')
axis[1,0].legend()
axis[0,1].plot(wavelength,F_imst)
axis[0,1].set_title(r'$1(c)\quad F^{IMST}$ vs $\lambda (nm)$')
axis[1,1].plot(wavelength,F_rom)
axis[1,1].set_title(r'$1(d)\quad F^{ROM}$ vs $\lambda (nm)$')
figure.tight_layout(pad=1.0)
plt.show()

img = cv2.imread('/content/fig5.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=871x661 at 0x7F8BDDF0AA60>

# %% [markdown]
# # **Tutorial Question : Linearly polarized Gaussian wave impinging on a low refractive index small dielectric particle**

# %% [markdown]
# Question: \\
# A linearly polarised Gaussian beam of light is impinged on a purely dielectric particle. The electric field is given by:
# \begin{equation}
#   \mathbf{E}=E_0 exp\left(-\frac{R^2}{\sigma^2}\right)exp(ikz) \hat x, \quad (R=\sqrt{x^2+y^2})
# \end{equation}
# Calculate the expression for real and imaginary forces on the particle

# %% [markdown]
# ##Solution

# %% [markdown]
# Given \begin{equation}
#   \mathbf{E}=E_0 exp\left(-\frac{R^2}{\sigma^2}\right)exp(ikz) \hat x, \quad (R=\sqrt{x^2+y^2})\quad .....(1)
# \end{equation}
# And similar form of magnetic field.\
# Using
# \begin{equation}
# \mathbf{P}^{O}_{e} = \mathbf{P}^{O}_{m} = \frac{1}{8πc} E^{2}_{o} exp(-\frac{R^2}{σ^2})
# \end{equation}
# In general, Force on moving charge particle is given by Lorentz force
# \begin{equation}
#  \mathbf{F} = q ( \mathbf{E} + \mathbf{v}\times \mathbf{B})
# \end{equation}
# In our problem we have linearly polarized gaussian beam incident on small particle which is **electrically dipolar**.\
# A dipole is the limit of two charges of equal magnitude and opposite sign spaced a distance d apart, in the limit
# \begin{equation}
# \lim_{\mathbf d \to 0} (q\mathbf d)  =  \mathbf p
# \end{equation}
# so the force experienced is
# \begin{equation}
# \mathbf{F}_{e} = q (\mathbf{E}(r+d) - \mathbf{E}(r))=(\mathbf{p} · Δ)\mathbf{E} \\
# \mathbf{F}_{m} = q(\mathbf{v}\times \mathbf{B}) = \frac{1}{c} \frac{d\mathbf{p}}{dt} × \mathbf{{B}}
# \end{equation}
# So Finally we have
# \begin{equation}
# \mathbf{F} = ( \mathbf{p} · Δ) \mathbf{E} + \frac{1}{c} \frac{d\mathbf{p}}{dt} × {\mathbf{B}}
# \end{equation}
# Putting $\mathbf{E} $ and $ \mathbf{B}$
# \begin{equation}
# F_i =\left[ ( \mathbf{p} · Δ) E + i k \frac{d\mathbf{p}}{dt} × \mathbf{B}\right]_i=\frac{1} {2}[α_{e} E{j}^{*}∂_{j}E_{i} + ik α^{*}_{e} ϵ_{ijk} E_{j}^{*} B_{k}]
# \end{equation}
# we used p =
# Since, $B_k = -\frac{i}{k}\epsilon_{klm}\partial_l E_m, \quad \epsilon_{ijk}\epsilon_{klm}=\delta_{il}\delta_{jm}-\delta_{im}\delta_{jl}$
# So, the complex force becomes,
# \begin{equation}
# F_i=\frac{1}{2}\alpha_e^*E_j^*\partial_i E_j \qquad \{i,j=1,2,3\}
# \end{equation}

# %% [markdown]
# This example is similar to example 2 except it has a gaussian profile.
#
# Using the equation for force on electric dipole from appendix E,
# \begin{equation}
# <F_i>=\frac{1}{2}Re\{\alpha_eE_j\partial_iE_j^*\}, \quad Im\{F_i\}=-\frac{1}{2}Im\{\alpha_eE_j\partial_iE_j^*\}
# \end{equation}
#
# Solving for x-component of time-averaged force:
# \begin{equation}
# <F_x>=\frac{1}{2} Re\{\alpha_e(E_x\partial_xE_x^*+E_y\partial_xE_y^*+E_z\partial_xE_z^*)\}
# \\
# E_y=E_z=0
# \\
# \partial_x E_x^*=\partial_x\left\{E_0^* exp\left(-\frac{x^2+y^2}{\sigma^2}\right)exp(-ikz)\right\} \\
# \implies \partial_x E_x^*=E_0^*\left(-\frac{2x}{\sigma^2}\right)exp\left(-\frac{x^2+y^2}{\sigma^2}\right)exp(-ikz) \\
# \implies E_x\partial_x E_x^*=|E_0|^2\left(-\frac{2x}{\sigma^2}\right)exp\left(-\frac{2x^2+2y^2}{\sigma^2}\right) \\
# \implies <F_x>=\frac{1}{2} Re\{\alpha_e(E_x\partial_xE_x^*)\}=\frac{1}{2}\alpha_e^R |E_0|^2\left(-\frac{2x}{\sigma^2}\right)exp\left(-\frac{2x^2+2y^2}{\sigma^2}\right)\\
# \implies <F_x>=-\alpha_e^R |E_0|^2\left(\frac{x}{\sigma^2}\right)exp\left(-\frac{2R^2}{\sigma^2}\right)\\
# \end{equation}
# Similarly, for y-component of force:
# \begin{equation}
# <F_y>=-\alpha_e^R |E_0|^2\left(\frac{y}{\sigma^2}\right)exp\left(-\frac{2R^2}{\sigma^2}\right)\\
# \end{equation}
# Now, for z-component:
# \begin{equation}
# <F_z>=\frac{1}{2} Re\{\alpha_e(E_x\partial_zE_x^*)\}\\
# \implies \partial_z E_x^*=E_0^*\left(-ik\right)exp\left(-\frac{R^2}{\sigma^2}\right)exp(-ikz) \\
# \implies E_x\partial_z E_x^*=|E_0|^2\left(-ik\right)exp\left(-\frac{2R^2}{\sigma^2}\right) \\
# \implies
# <F_z>=\frac{1}{2} Re\{\alpha_e(E_x\partial_zE_x^*)\}=\frac{1}{2}k\alpha^I_e|E_0|^2exp\left(-\frac{2R^2}{\sigma^2}\right)\\
# \end{equation}
# This gives real force:
# \begin{equation}
# <\mathbf{F}>=|E_0|^2exp\left(-\frac{2R^2}{\sigma^2}\right)\left[-\frac{\alpha^R_e}{\sigma^2}(\mathbf{x}+\mathbf{y})+\frac{k\alpha^I_e}{2}\mathbf{\hat z}\right]
# \end{equation}
# Now, solving for imaginary part of force:
# \begin{equation}
# Im\{\mathbf{F}\} = |E_0|^2exp\left(-\frac{2R^2}{\sigma^2}\right)\left[\frac{\alpha^I_e}{\sigma^2}(\mathbf{x}+\mathbf{y})+\frac{k\alpha^R_e}{2}\mathbf{\hat{z}}\right]
# \end{equation}

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conculsion, this paper demonstrates the existence of complex forces in the paradigm of light matter-interactions completing the entire picture of optical emergence. The paper formulates Imaginary Maxwell Stress Tensor (IMST) which is associated with with generation of reactive strength of orbital momentum and this storage of reactive momentum gives rise of imaginary lorentz force (ILF) which gives us a glimse of other side of dynamical effects of light-matter interaction.
#
# The ILF and ROM play a hindrance role versus the standard RLF, so that a large ROM storage conveys a loss of radiative force, i.e., of RLF, and vice-versa. This is illustrated with examples and makes the ROM and ILF indirectly observable.
#
# The work illustrates the complementary roles of reactive strength of orbital momentum and the time averaged poynting momentum. As the RLF is characterized by the flow of RMST across a far-zone surface sphere, and it is independent of its radius, the stored ROM, and its associated ILF, are characterized by the flow of IMST across a near-field sphere that surrounds the distribution of charges and currents. Therefore, the ROM acts as a force “reactance” on the body.

# %% [markdown]
# # **Application (Radio-frequency Antennas)**

# %% [markdown]
# Like in the design of RF antennas and nanoantennas the radiation efficiency is increased by diminishing the reactive power and reactive work, in the context of optical manipulation one may act on the ROM and ILF in order to optimize the time-averaged optical force. So the scenario established in this study contains a novel tool to handle the mechanical action of light on matter.

# %% [markdown]
# # References

# %% [markdown]
# [1] Refractive index for gold: https://www.filmetrics.com/refractive-index-database/Au \\
# [2] Supplementary material: https://static-content.springer.com/esm/art%3A10.1038%2Fs41377-022-00979-2/MediaObjects/41377_2022_979_MOESM1_ESM.pdf \\
# [3] Wikipedia and some other research papers from internet. \\
# [4] Reference papers given in paper. \\
# [5]https://www.sciencedirect.com/science/article/pii/S0030402622017107?via%3Dihub \\
# [6]https://web.mit.edu/6.013_book/www/chapter11/11.8.html#:~:text=The%20total%20force%20on%20the,charge%2C%20the%20separate%20contributions%20cancel

# %% [markdown]
# # Contributions

# %% [markdown]
# Hemanth Reddy (200260013): Understood the general flow of paper, contributed in making notebook.
#
# Kaushik Dhandekar (200260023): Understood The CMST derivation and examples, plotted the plots, tried to understand about effects on magnetoelectric particle mentioned in paper.
#
# Piyush Mourya (200260037): Framed and solved tut problem. Understood Instantaneous MST part of the paper.
#
# Rishank Meshram (200260042): Understood all the equations and theory of the paper. Understood the plots and helped in figuring out their meaning.
